# %%
from pandas import read_csv,read_excel

# %%
map = read_csv("C:/Users/Raeni/PycharmProjects/Spring2025/DSC640/Datasets/Week5&6/carTheftsMap.csv").fillna(0)
kia_data = read_csv("C:/Users/Raeni/PycharmProjects/Spring2025/DSC640/Datasets/Week5&6/KiaHyundaiMilwaukeeData.csv").fillna(0)
kia_thefts = read_csv("C:/Users/Raeni/PycharmProjects/Spring2025/DSC640/Datasets/Week5&6/kiaHyundaiThefts.csv").fillna(0)
vice_news = read_excel("C:/Users/Raeni/PycharmProjects/Spring2025/DSC640/Datasets/Week5&6/VICE_News_Theft_Data.xlsx", header=[0, 1]).fillna(0)

# %%
map
# Out:
#     agency_ori                              geo_name countCarThefts2019  \
# 0    MO0490300                           Carthage PD                 62
# 1            0                      Warren County SO                112
# 2      TX06802                             Odessa PD                499
# 3    MO0530000                     Laclede County SO                 55
# 4    MO0480000                     Jackson County SO                125
# ..         ...                                   ...                ...
# 551  MN0272000                         St Anthony PD                 10
# 552    VT00401                         Burlington PD                 55
# 553  PA0063500             Central Berks Regional PD                  5
# 554  PAPSP1100  PA State Police - Pittsburgh Station                  7
# 555  PAPEP0000                  Philadelphia City PD               5570
#
#     countCarThefts2020 countCarThefts2021 countCarThefts2022   latitude  \
# ...

# %%
kia_data
# Out:
#    month  year       city state  countKiaHyundaiThefts  countOtherThefts  \
# 0    Jan  2019  Milwaukee    WI                     22               235
# 1    Feb  2019  Milwaukee    WI                     13               218
# 2    Mar  2019  Milwaukee    WI                     10               195
# 3    Apr  2019  Milwaukee    WI                     10               238
# 4    May  2019  Milwaukee    WI                     11               280
# 5    Jun  2019  Milwaukee    WI                     15               330
# 6    Jul  2019  Milwaukee    WI                     25               295
# 7    Aug  2019  Milwaukee    WI                     21               352
# 8    Sep  2019  Milwaukee    WI                     18               256
# 9    Oct  2019  Milwaukee    WI                     25               266
# 10   Nov  2019  Milwaukee    WI                     14               309
# 11   Dec  2019  Milwaukee    WI                     23               307
# ...

# %%
kia_thefts
# Out:
#     month  year           city state  countKiaHyundaiThefts  countOtherThefts  \
# 0     Jan  2019        Atlanta    GA                     17               264
# 1     Feb  2019        Atlanta    GA                     11               205
# 2     Mar  2019        Atlanta    GA                     18               181
# 3     Apr  2019        Atlanta    GA                     15               223
# 4     May  2019        Atlanta    GA                     16               277
# ..    ...   ...            ...   ...                    ...               ...
# 547   Aug  2022  Washington DC     0                     37               280
# 548   Sep  2022  Washington DC     0                     32               295
# 549   Oct  2022  Washington DC     0                     62               274
# 550   Nov  2022  Washington DC     0                     91               275
# 551   Dec  2022  Washington DC     0                    150               293
#
#      percentKiaHyundai
# ...

# %%
vice_news.columns = ['_'.join([str(a), str(b)]).strip() for a, b in vice_news.columns]
vice_news.rename(columns={vice_news.columns[0]: 'Date'}, inplace=True)
vice_news
# Out:
#          Date  Denver_Kia/Hyundais  Denver_All  Denver_Percent  \
# 0  2019-12-01                 48.0       615.0        0.078049
# 1  2020-01-01                 21.0       519.0        0.040462
# 2  2020-02-01                 28.0       402.0        0.069652
# 3  2020-03-01                 35.0       508.0        0.068898
# 4  2020-04-01                 39.0       616.0        0.063312
# 5  2020-05-01                 37.0       692.0        0.053468
# 6  2020-06-01                 57.0       747.0        0.076305
# 7  2020-07-01                 57.0       786.0        0.072519
# 8  2020-08-01                 85.0       840.0        0.101190
# 9  2020-09-01                107.0       916.0        0.116812
# 10 2020-10-01                112.0       942.0        0.118896
# 11 2020-11-01                155.0       948.0        0.163502
# 12 2020-12-01                163.0      1014.0        0.160750
# 13 2021-01-01                209.0      1039.0        0.201155
# ...
